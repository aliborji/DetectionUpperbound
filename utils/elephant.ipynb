# %%
import json
import pickle
import os
import numpy as np

# %%
source_path = '/home/ali/markable-production/object_detection_context/datasets/elephant_data/coco/'

# %%
with open(os.path.join(source_path, '45_202_bear_chair', 'data.pk2'), 'rb') as f:
    data = pickle.load(f, encoding='latin1')

# %%
data.keys()
# Out:
# dict_keys(['img1', 'mask1', 'bkg'])

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(data['img1'])
plt.show()

# %%
# plt.imshow(data['mask1'])
# plt.show()
aa = data['mask1'].astype('int')
bb = data['bkg'].astype('int')

# %%
plt.imshow(aa[:,:,0])

# %%
plt.imshow(bb[:,:,0])
